# %% [markdown]
# ## Assignment 9: Data Visualization
#
# Dr. Erdogan Dogdu
#
# In this exercise we will be working with a new COVID-19 dataset.
#
# This data comes from <a href="https://www.nytimes.com/article/coronavirus-county-data-us.html">New York Times</a>.
#
# Here is the data file we will be working with: <a href="https://github.com/nytimes/covid-19-data/blob/master/us-states.csv">data</a>. It has these columns: date, state, fips, cases, deaths
#
# Download the file to your computer first, by (1) click and open the file, (2) click on Raw button, (3) press Ctrl-S to save into your computer.
#
# 1. Complete the following tasks.
# * Rename this notebook file as asg9_firstname_lastname
# * Submit to BB (not gradescope)
#
# Help: Reading Titanic data and plotting some numbers (scatter plot) is shown here https://github.com/edogdu/intro_to_python/blob/master/ch12_visualization.ipynb

# %% [markdown]
# ### Task 1: Complete the following to plot the number of cases for two states (TX and NY)

# %%
# write this function count_state that will read the file, 
# and find the records for the state 'which' (parameter),
# and return a dictionary with dates as keys, and the number of cases as values for that state

def count_state(which):
    # open the data file 'us-states.csv'

    
    # read the first headers line from the file and skip


    # find the state's number of cases by days
    # make a dictionary with the key as the date, and the value as the number of cases

    
    
    
    
    # return the dictionary

# %%
# get the dictionary for Texas
tx_counts = ....
# get the dictionary for New York
ny_counts = ....

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Plot the number of cases for both states by date
plt.figure(figsize=(10, 5), dpi=80)

# plot TX numbers

# plot NY numbers

# plot legends, title, ..,
plt.title('NY vs TX',fontsize=20)
plt.xlabel('Date', fontsize=15, color='blue')
plt.ylabel('Cases', fontsize=15, color='blue')

# input the list of dates in xticks parameter (instead of ....)
plt.xticks(....)[::2],rotation='vertical')
plt.show()

# %% [markdown]
# ### Task 2: Use the same data file and plot a "bar graph" of your choice
#
# Examples:
#
# - Weekly (every 7 days) total number of cases for a state or for all states
# * Weekly percentage of deaths out of the number of cases for a state or for all states
# * or anything else

# %%
# your code goes here
